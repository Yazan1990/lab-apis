# %% [markdown]
# # 1. Read your exported json file from the data folder

# %%
import json
import pandas as pd

with open("data/coffe_shops.json", "r", encoding="utf-8") as f:
    data = json.load(f)

geo = pd.DataFrame(data["results"])  # <-- only the list of places
geo.shape
# Out:
# (5, 16)

# %% [markdown]
# # 2. Plot a map with the coffee shops

# %%
import geopandas as gdp
from cartoframes.viz import Map, Layer, popup_element
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 import geopandas as gdp
# ----> 2 from cartoframes.viz import Map, Layer, popup_element
#
# ModuleNotFoundError: No module named 'cartoframes'

# %% [markdown]
# After pushing, view your own notebook on [nbviewer](https://nbviewer.org/)
